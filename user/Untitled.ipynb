# %%
import requests
help(requests.post)
# Out:
# Help on function post in module requests.api:
#
# post(url, data=None, json=None, **kwargs)
#     Sends a POST request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param data: (optional) Dictionary, list of tuples, bytes, or file-like
#         object to send in the body of the :class:`Request`.
#     :param json: (optional) json data to send in the body of the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %%
import json

# %%
import requests

import django.shortcuts
help(django.shortcuts.render)
# Out:
# Help on function render in module django.shortcuts:
#
# render(request, template_name, context=None, content_type=None, status=None, using=None)
#     Returns a HttpResponse whose content is filled with the result of calling
#     django.template.loader.render_to_string() with the passed arguments.

# %%
help(requests.session)
# Out:
# Help on function session in module requests.sessions:
#
# session()
#     Returns a :class:`Session` for context-management.
#
#     .. deprecated:: 1.0.0
#
#         This method has been deprecated since version 1.0.0 and is only kept for
#         backwards compatibility. New code should use :class:`~requests.sessions.Session`
#         to create a session. This may be removed at a future date.
#
#     :rtype: Session

# %%
import hashlib
help(hashlib)
# Out:
# Help on module hashlib:
#
# NAME
#     hashlib - hashlib module - A common interface to many hash functions.
#
# DESCRIPTION
#     new(name, data=b'', **kwargs) - returns a new hash object implementing the
#                                     given hash function; initializing the hash
#                                     using the given binary data.
#
#     Named constructor functions are also available, these are faster
#     than using new(name):
#
#     md5(), sha1(), sha224(), sha256(), sha384(), sha512(), blake2b(), blake2s(),
#     sha3_224, sha3_256, sha3_384, sha3_512, shake_128, and shake_256.
#
#     More algorithms may be available on your platform but the above are guaranteed
#     to exist.  See the algorithms_guaranteed and algorithms_available attributes
#     to find out what algorithm names can be passed to new().
#
#     NOTE: If you want the adler32 or crc32 hash functions they are available in
#     the zlib module.
#
#     Choose your hash function wisely.  Some have known collision weaknesses.
#     sha384 and sha512 will be slow on 32 bit platforms.
#
#     Hash objects have these methods:
#      - update(data): Update the hash object with the bytes in data. Repeated calls
#                      are equivalent to a single call with the concatenation of all
#                      the arguments.
#      - digest():     Return the digest of the bytes passed to the update() method
#                      so far as a bytes object.
#      - hexdigest():  Like digest() except the digest is returned as a string
#                      of double length, containing only hexadecimal digits.
#      - copy():       Return a copy (clone) of the hash object. This can be used to
#                      efficiently compute the digests of datas that share a common
#                      initial substring.
#
#     For example, to obtain the digest of the byte string 'Nobody inspects the
#     spammish repetition':
#
#         >>> import hashlib
#         >>> m = hashlib.md5()
#         >>> m.update(b"Nobody inspects")
#         >>> m.update(b" the spammish repetition")
#         >>> m.digest()
#         b'\xbbd\x9c\x83\xdd\x1e\xa5\xc9\xd9\xde\xc9\xa1\x8d\xf0\xff\xe9'
#
#     More condensed:
#
#         >>> hashlib.sha224(b"Nobody inspects the spammish repetition").hexdigest()
#         'a4337bc45a8fc544c03f52dc550cd6e1e87021bc896588bd79e901e2'
#
# CLASSES
#     builtins.object
#         _blake2.blake2b
#         _blake2.blake2s
#         _sha3.sha3_224
#         _sha3.sha3_256
#         _sha3.sha3_384
#         _sha3.sha3_512
#         _sha3.shake_128
#         _sha3.shake_256
#
#     class blake2b(builtins.object)
#      |  blake2b(data=b'', /, *, digest_size=64, key=b'', salt=b'', person=b'', fanout=1, depth=1, leaf_size=0, node_offset=0, node_depth=0, inner_size=0, last_node=False)
#      |
#      |  Return a new BLAKE2b hash object.
#      |
#      |  Methods defined here:
#      |
#      |  copy(self, /)
#      |      Return a copy of the hash object.
#      |
#      |  digest(self, /)
#      |      Return the digest value as a bytes object.
#      |
#      |  hexdigest(self, /)
#      |      Return the digest value as a string of hexadecimal digits.
#      |
#      |  update(self, data, /)
#      |      Update this hash object's state with the provided bytes-like object.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  block_size
#      |
#      |  digest_size
#      |
#      |  name
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  MAX_DIGEST_SIZE = 64
#      |
#      |  MAX_KEY_SIZE = 64
#      |
#      |  PERSON_SIZE = 16
#      |
#      |  SALT_SIZE = 16
#
#     class blake2s(builtins.object)
#      |  blake2s(data=b'', /, *, digest_size=32, key=b'', salt=b'', person=b'', fanout=1, depth=1, leaf_size=0, node_offset=0, node_depth=0, inner_size=0, last_node=False)
#      |
#      |  Return a new BLAKE2s hash object.
#      |
#      |  Methods defined here:
#      |
#      |  copy(self, /)
#      |      Return a copy of the hash object.
#      |
#      |  digest(self, /)
#      |      Return the digest value as a bytes object.
#      |
#      |  hexdigest(self, /)
#      |      Return the digest value as a string of hexadecimal digits.
#      |
#      |  update(self, data, /)
#      |      Update this hash object's state with the provided bytes-like object.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  block_size
#      |
#      |  digest_size
#      |
#      |  name
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  MAX_DIGEST_SIZE = 32
#      |
#      |  MAX_KEY_SIZE = 32
#      |
#      |  PERSON_SIZE = 8
#      |
#      |  SALT_SIZE = 8
#
#     class sha3_224(builtins.object)
#      |  sha3_224([data]) -> SHA3 object
#      |
#      |  Return a new SHA3 hash object with a hashbit length of 28 bytes.
#      |
#      |  Methods defined here:
#      |
#      |  copy(self, /)
#      |      Return a copy of the hash object.
#      |
#      |  digest(self, /)
#      |      Return the digest value as a bytes object.
#      |
#      |  hexdigest(self, /)
#      |      Return the digest value as a string of hexadecimal digits.
#      |
#      |  update(self, data, /)
#      |      Update this hash object's state with the provided bytes-like object.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  block_size
#      |
#      |  digest_size
#      |
#      |  name
#
#     class sha3_256(builtins.object)
#      |  sha3_256([data]) -> SHA3 object
#      |
#      |  Return a new SHA3 hash object with a hashbit length of 32 bytes.
#      |
#      |  Methods defined here:
#      |
#      |  copy(self, /)
#      |      Return a copy of the hash object.
#      |
#      |  digest(self, /)
#      |      Return the digest value as a bytes object.
#      |
#      |  hexdigest(self, /)
#      |      Return the digest value as a string of hexadecimal digits.
#      |
#      |  update(self, data, /)
#      |      Update this hash object's state with the provided bytes-like object.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  block_size
#      |
#      |  digest_size
#      |
#      |  name
#
#     class sha3_384(builtins.object)
#      |  sha3_384([data]) -> SHA3 object
#      |
#      |  Return a new SHA3 hash object with a hashbit length of 48 bytes.
#      |
#      |  Methods defined here:
#      |
#      |  copy(self, /)
#      |      Return a copy of the hash object.
#      |
#      |  digest(self, /)
#      |      Return the digest value as a bytes object.
#      |
#      |  hexdigest(self, /)
#      |      Return the digest value as a string of hexadecimal digits.
#      |
#      |  update(self, data, /)
#      |      Update this hash object's state with the provided bytes-like object.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  block_size
#      |
#      |  digest_size
#      |
#      |  name
#
#     class sha3_512(builtins.object)
#      |  sha3_512([data]) -> SHA3 object
#      |
#      |  Return a new SHA3 hash object with a hashbit length of 64 bytes.
#      |
#      |  Methods defined here:
#      |
#      |  copy(self, /)
#      |      Return a copy of the hash object.
#      |
#      |  digest(self, /)
#      |      Return the digest value as a bytes object.
#      |
#      |  hexdigest(self, /)
#      |      Return the digest value as a string of hexadecimal digits.
#      |
#      |  update(self, data, /)
#      |      Update this hash object's state with the provided bytes-like object.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  block_size
#      |
#      |  digest_size
#      |
#      |  name
#
#     class shake_128(builtins.object)
#      |  shake_128([data]) -> SHAKE object
#      |
#      |  Return a new SHAKE hash object.
#      |
#      |  Methods defined here:
#      |
#      |  copy(self, /)
#      |      Return a copy of the hash object.
#      |
#      |  digest(self, length, /)
#      |      Return the digest value as a bytes object.
#      |
#      |  hexdigest(self, length, /)
#      |      Return the digest value as a string of hexadecimal digits.
#      |
#      |  update(self, data, /)
#      |      Update this hash object's state with the provided bytes-like object.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  block_size
#      |
#      |  digest_size
#      |
#      |  name
#
#     class shake_256(builtins.object)
#      |  shake_256([data]) -> SHAKE object
#      |
#      |  Return a new SHAKE hash object.
#      |
#      |  Methods defined here:
#      |
#      |  copy(self, /)
#      |      Return a copy of the hash object.
#      |
#      |  digest(self, length, /)
#      |      Return the digest value as a bytes object.
#      |
#      |  hexdigest(self, length, /)
#      |      Return the digest value as a string of hexadecimal digits.
#      |
#      |  update(self, data, /)
#      |      Update this hash object's state with the provided bytes-like object.
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  block_size
#      |
#      |  digest_size
#      |
#      |  name
#
# FUNCTIONS
#     md5 = openssl_md5(...)
#         Returns a md5 hash object; optionally initialized with a string
#
#     new = __hash_new(name, data=b'', **kwargs)
#         new(name, data=b'') - Return a new hashing object using the named algorithm;
#         optionally initialized with data (which must be a bytes-like object).
#
#     pbkdf2_hmac(...)
#         pbkdf2_hmac(hash_name, password, salt, iterations, dklen=None) -> key
#
#         Password based key derivation function 2 (PKCS #5 v2.0) with HMAC as
#         pseudorandom function.
#
#     sha1 = openssl_sha1(...)
#         Returns a sha1 hash object; optionally initialized with a string
#
#     sha224 = openssl_sha224(...)
#         Returns a sha224 hash object; optionally initialized with a string
#
#     sha256 = openssl_sha256(...)
#         Returns a sha256 hash object; optionally initialized with a string
#
#     sha384 = openssl_sha384(...)
#         Returns a sha384 hash object; optionally initialized with a string
#
#     sha512 = openssl_sha512(...)
#         Returns a sha512 hash object; optionally initialized with a string
#
# DATA
#     __all__ = ('md5', 'sha1', 'sha224', 'sha256', 'sha384', 'sha512', 'bla...
#     algorithms_available = {'BLAKE2b512', 'BLAKE2s256', 'MD4', 'MD5', 'MD5...
#     algorithms_guaranteed = {'blake2b', 'blake2s', 'md5', 'sha1', 'sha224'...
#
# FILE
#     d:\study\jet\anaconda\envs\tensorflow\lib\hashlib.py

# %%
import json
from django.shortcuts import render
ret_msg = {'user_id':111, 'login_status':0}
a = json.dumps(ret_msg)
req = None
c = render(req, '/', a)
print(c.json())
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-47-cfe6bdec2052> in <module>
#       4 a = json.dumps(ret_msg)
#       5 req = None
# ----> 6 c = render(req, '/', a)
#       7 print(c.json())
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\shortcuts.py in render(request, template_name, context, content_type, status, using)
#      28     django.template.loader.render_to_string() with the passed arguments.
#      29     """
# ---> 30     content = loader.render_to_string(template_name, context, request, using=using)
#      31     return HttpResponse(content, content_type, status)
#      32
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\template\loader.py in render_to_string(template_name, context, request, using)
#      65         template = select_template(template_name, using=using)
#      66     else:
# ---> 67         template = get_template(template_name, using=using)
#      68     return template.render(context, request)
#      69
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\template\loader.py in get_template(template_name, using)
#      16     """
#      17     chain = []
# ---> 18     engines = _engine_list(using)
#      19     for engine in engines:
#      20         try:
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\template\loader.py in _engine_list(using)
#      70
#      71 def _engine_list(using=None):
# ---> 72     return engines.all() if using is None else [engines[using]]
#      73
#      74
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\template\utils.py in all(self)
#      87
#      88     def all(self):
# ---> 89         return [self[alias] for alias in self]
#      90
#      91
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\template\utils.py in __iter__(self)
#      84
#      85     def __iter__(self):
# ---> 86         return iter(self.templates)
#      87
#      88     def all(self):
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\utils\functional.py in __get__(self, instance, cls)
#      33         if instance is None:
#      34             return self
# ---> 35         res = instance.__dict__[self.name] = self.func(instance)
#      36         return res
#      37
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\template\utils.py in templates(self)
#      27     def templates(self):
#      28         if self._templates is None:
# ---> 29             self._templates = settings.TEMPLATES
#      30
#      31         templates = OrderedDict()
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      54         """
#      55         if self._wrapped is empty:
# ---> 56             self._setup(name)
#      57         val = getattr(self._wrapped, name)
#      58         self.__dict__[name] = val
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      37                 "You must either define the environment variable %s "
#      38                 "or call settings.configure() before accessing settings."
# ---> 39                 % (desc, ENVIRONMENT_VARIABLE))
#      40
#      41         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting TEMPLATES, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.

# %%
from django.db import models

class User(models.Model):
    gender = (
        ('male', "男"),
        ('female', "女"),
        ('secret',"保密")
    )
    # id = models.AutoField() Django 默认创建自增主键
    nickname = models.CharField(max_length=32)
    email = models.EmailField(default="123@qq.com",unique=True)
    sex = models.CharField(max_length=32,choices=gender,default="保密")
    birthday = models.DateField(default="1998-06-02")
    access = models.IntegerField(default=1)
    icon = models.ImageField()
    def __str__(self):
        return self.id
    def create_newuser(self,i_type,identifier,pwd):
        try:
            self.user_auth_set.create(identity_type=i_type,identifier=identifier,credential=pwd)
        except:
            pass
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-1-b3fa6083f9a5> in <module>
#       1 from django.db import models
#       2
# ----> 3 class User(models.Model):
#       4     gender = (
#       5         ('male', "男"),
#
# <ipython-input-1-b3fa6083f9a5> in User()
#       8     )
#       9     # id = models.AutoField() Django 默认创建自增主键
# ---> 10     nickname = models.CharField(max_length=32)
#      11     email = models.EmailField(default="123@qq.com",unique=True)
#      12     sex = models.CharField(max_length=32,choices=gender,default="保密")
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\db\models\fields\__init__.py in __init__(self, *args, **kwargs)
#    1059
#    1060     def __init__(self, *args, **kwargs):
# -> 1061         super(CharField, self).__init__(*args, **kwargs)
#    1062         self.validators.append(validators.MaxLengthValidator(self.max_length))
#    1063
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\db\models\fields\__init__.py in __init__(self, verbose_name, name, primary_key, max_length, unique, blank, null, db_index, rel, default, editable, serialize, unique_for_date, unique_for_month, unique_for_year, choices, help_text, db_column, db_tablespace, auto_created, validators, error_messages)
#     170         self.db_index = db_index
#     171         self.db_column = db_column
# --> 172         self.db_tablespace = db_tablespace or settings.DEFAULT_INDEX_TABLESPACE
#     173         self.auto_created = auto_created
#     174
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      54         """
#      55         if self._wrapped is empty:
# ---> 56             self._setup(name)
#      57         val = getattr(self._wrapped, name)
#      58         self.__dict__[name] = val
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      37                 "You must either define the environment variable %s "
#      38                 "or call settings.configure() before accessing settings."
# ---> 39                 % (desc, ENVIRONMENT_VARIABLE))
#      40
#      41         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting DEFAULT_INDEX_TABLESPACE, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.

# %%
help(models)
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-2-e817749cc599> in <module>
# ----> 1 help(models)
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\_sitebuiltins.py in __call__(self, *args, **kwds)
#     101     def __call__(self, *args, **kwds):
#     102         import pydoc
# --> 103         return pydoc.help(*args, **kwds)
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in __call__(self, request)
#    1893     def __call__(self, request=_GoInteractive):
#    1894         if request is not self._GoInteractive:
# -> 1895             self.help(request)
#    1896         else:
#    1897             self.intro()
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in help(self, request)
#    1952             else: doc(str, 'Help on %s:', output=self._output)
#    1953         elif isinstance(request, Helper): self()
# -> 1954         else: doc(request, 'Help on %s:', output=self._output)
#    1955         self.output.write('\n')
#    1956
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in doc(thing, title, forceload, output)
#    1672     try:
#    1673         if output is None:
# -> 1674             pager(render_doc(thing, title, forceload))
#    1675         else:
#    1676             output.write(render_doc(thing, title, forceload, plaintext))
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in render_doc(thing, title, forceload, renderer)
#    1665         object = type(object)
#    1666         desc += ' object'
# -> 1667     return title % desc + '\n\n' + renderer.document(object, name)
#    1668
#    1669 def doc(thing, title='Python Library Documentation: %s', forceload=0,
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in document(self, object, name, *args)
#     383         if inspect.ismemberdescriptor(object): return self.docdata(*args)
#     384         try:
# --> 385             if inspect.ismodule(object): return self.docmodule(*args)
#     386             if inspect.isclass(object): return self.docclass(*args)
#     387             if inspect.isroutine(object): return self.docroutine(*args)
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in docmodule(self, object, name, mod)
#    1181                 inspect.getclasstree(classlist, 1), name)]
#    1182             for key, value in classes:
# -> 1183                 contents.append(self.document(value, key, name))
#    1184             result = result + self.section('CLASSES', '\n'.join(contents))
#    1185
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in document(self, object, name, *args)
#     384         try:
#     385             if inspect.ismodule(object): return self.docmodule(*args)
# --> 386             if inspect.isclass(object): return self.docclass(*args)
#     387             if inspect.isroutine(object): return self.docroutine(*args)
#     388         except AttributeError:
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in docclass(self, object, name, mod, *ignored)
#    1341                                      lambda t: t[1] == 'data descriptor')
#    1342             attrs = spilldata("Data and other attributes %s:\n" % tag, attrs,
# -> 1343                               lambda t: t[1] == 'data')
#    1344
#    1345             assert attrs == []
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in spilldata(msg, attrs, predicate)
#    1305                     except AttributeError:
#    1306                         obj = homecls.__dict__[name]
# -> 1307                     push(self.docother(obj, name, mod, maxlen=70, doc=doc) +
#    1308                          '\n')
#    1309             return attrs
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in docother(self, object, name, mod, parent, maxlen, doc)
#    1428     def docother(self, object, name=None, mod=None, parent=None, maxlen=None, doc=None):
#    1429         """Produce text documentation for a data object."""
# -> 1430         repr = self.repr(object)
#    1431         if maxlen:
#    1432             line = (name and name + ' = ' or '') + repr
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\reprlib.py in repr(self, x)
#      50
#      51     def repr(self, x):
# ---> 52         return self.repr1(x, self.maxlevel)
#      53
#      54     def repr1(self, x, level):
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in repr1(self, x, level)
#    1051             methodname = 'repr_' + '_'.join(type(x).__name__.split())
#    1052             if hasattr(self, methodname):
# -> 1053                 return getattr(self, methodname)(x, level)
#    1054         return cram(stripid(repr(x)), self.maxother)
#    1055
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\reprlib.py in repr_dict(self, x, level)
#     112         for key in islice(_possibly_sorted(x), self.maxdict):
#     113             keyrepr = repr1(key, newlevel)
# --> 114             valrepr = repr1(x[key], newlevel)
#     115             pieces.append('%s: %s' % (keyrepr, valrepr))
#     116         if n > self.maxdict: pieces.append('...')
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\pydoc.py in repr1(self, x, level)
#    1052             if hasattr(self, methodname):
#    1053                 return getattr(self, methodname)(x, level)
# -> 1054         return cram(stripid(repr(x)), self.maxother)
#    1055
#    1056     def repr_string(self, x, level):
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\utils\functional.py in __repr__(self)
#      77
#      78         def __repr__(self):
# ---> 79             return repr(self.__cast())
#      80
#      81         @classmethod
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\utils\functional.py in __cast(self)
#     129                 return self.__bytes_cast()
#     130             elif self._delegate_text:
# --> 131                 return self.__text_cast()
#     132             else:
#     133                 return func(*self.__args, **self.__kw)
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\utils\functional.py in __text_cast(self)
#     117
#     118         def __text_cast(self):
# --> 119             return func(*self.__args, **self.__kw)
#     120
#     121         def __bytes_cast(self):
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\utils\translation\__init__.py in ugettext(message)
#      87
#      88 def ugettext(message):
# ---> 89     return _trans.ugettext(message)
#      90
#      91
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\utils\translation\__init__.py in __getattr__(self, real_name)
#      57     def __getattr__(self, real_name):
#      58         from django.conf import settings
# ---> 59         if settings.USE_I18N:
#      60             from django.utils.translation import trans_real as trans
#      61         else:
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\conf\__init__.py in __getattr__(self, name)
#      54         """
#      55         if self._wrapped is empty:
# ---> 56             self._setup(name)
#      57         val = getattr(self._wrapped, name)
#      58         self.__dict__[name] = val
#
# D:\Study\jet\Anaconda\envs\tensorflow\lib\site-packages\django\conf\__init__.py in _setup(self, name)
#      37                 "You must either define the environment variable %s "
#      38                 "or call settings.configure() before accessing settings."
# ---> 39                 % (desc, ENVIRONMENT_VARIABLE))
#      40
#      41         self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting USE_I18N, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
